# %% [markdown]
# PSEUDOCODE FOR STORE CHECKOUT
#
# START
# INPUT - List of prices of items bought quantity
# DECISION - Do you want to add/remove items: if yes, back to input; if no, continue
# COMPUTE - Sum of prices of items bought * quantity
# PRINT - Total
# DECISION - Do you want to check out? If yes, continue; if no, back to first decision.
# END

# %% [markdown]
# ![image.png](attachment:48adef87-6773-4739-bb3f-2c9f033ee58f.png)![image.png](attachment:fb11219f-b629-4a56-809d-4ddefd2b687f.png)

# %% [markdown]
# ![image.png](attachment:8035d064-c1f3-4100-b3c9-ed79601a3e75.png)![image.png](attachment:74a71567-4a36-4f78-9fe8-157313378265.png)
