# %% [markdown]
# START
#
# IMPORT: pandas
#
# CREATE: lists for girls names, ages, heights, and scores.
#
# CREATE: lists for boys names, ages, heights, and scores.
#
# CONVERT: lists to tables
#
# DISPLAY: Tables
#
# END

# %%
# using pandas to create tables

import pandas as pd

# create lists for girls information
girls_data = {
    "Name": ["Evelyn", "Jessica", "Somto", "Edith", "Liza",
             "Madonna", "Waje", "Tola", "Aisha", "Latifa"],
    
    "Age": [17,16,17,18,16,18,17,20,19,17],
    
    "Height": [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5],
    
    "Score": [80,85,70,60,76,66,87,95,50,49]
}

# Create list for boys information
boys_data = {
    "Name": ["Chinedu","Liam","Wale","Gbenga","Abiola",
             "Kola","Kunle","George","Thomas","Wesley"],
    
    "Age": [19,16,18,17,20,19,16,18,17,19],
    
    "Height": [5.7,5.9,5.8,6.1,5.9,5.5,5.6,5.4,5.8,5.7],
    
    "Score": [74,87,75,68,66,78,87,98,54,60]
}

# Arranging infromationsinto
girls_list = pd.DataFrame(girls_data)
boys_list = pd.DataFrame(boys_data)

print("Girls Table")
print(girls_list)

print("\nBoys Table")
print(boys_list)
# Out:
# Girls Table
#       Name  Age  Height  Score
# 0   Evelyn   17     5.5     80
# 1  Jessica   16     6.0     85
# 2    Somto   17     5.4     70
# 3    Edith   18     5.9     60
# 4     Liza   16     5.6     76
# 5  Madonna   18     5.5     66
# 6     Waje   17     6.1     87
# 7     Tola   20     6.0     95
# 8    Aisha   19     5.7     50
# 9   Latifa   17     5.5     49
#
# Boys Table
#       Name  Age  Height  Score
# 0  Chinedu   19     5.7     74
# 1     Liam   16     5.9     87
# 2     Wale   18     5.8     75
# 3   Gbenga   17     6.1     68
# 4   Abiola   20     5.9     66
# 5     Kola   19     5.5     78
# 6    Kunle   16     5.6     87
# 7   George   18     5.4     98
# 8   Thomas   17     5.8     54
# 9   Wesley   19     5.7     60
